# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(style='ticks')
iris = pd.read_csv('iris.csv', header=None) 
iris.columns=['sepal_length', 'sepal_width', 'petal_length',
             'petal_width', 'species']
sns.pairplot(iris, hue="species", diag_kind="kde", 
            palette="muted")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.figure(figsize=(20,10), dpi=150)
wine = pd.read_csv('wine.csv')
wine_corr = wine.corr() #计算相关系数举证
plt.figure(figsize=(20,10))
sns.heatmap(wine_corr, annot=True, square=True, fmt='.2f')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set(style='ticks')
iris = pd.read_csv('iris.csv', header=None)
iris.columns=['sepal_length', 'speal_width', 'petal_length', 
             'petal_width', 'species']
sns.boxplot(x=iris['sepal_length'], data=iris)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['STHeiti']
df = sns.load_dataset('iris')
#设置x,y轴及数据源
ax = sns.boxplot(x="species", y='sepal_length', data=df)
#计算每组中的中位数
#medians = df.groupby(['species'])['sepal_length'].median().values
medians = df.pivot_table(index='species', values="sepal_length", 
                        aggfunc="median").values
#形成要显示的文本:每个子类的数量
nobs = df['species'].value_counts().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["数量:" + i for i in nobs]

#设置要显示的箱形图的数量
pos = range(len(nobs))
#将文本分别显示在中位数的上访
for tick, label in zip(pos, ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.03, nobs[tick],
           horizontalalignment='center', 
           size = 'x-small',
           color='w', 
           weight='semibold')
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#导出数据集
df = sns.load_dataset("iris")

#设置一行两列共两个子图
fig, axes = plt.subplots(1,2,sharey=True) #共享坐标轴
#绘制左子图
sns.boxplot(x="species", y="petal_width", data=df, ax=axes[0])
#绘制右子图
#sns.boxplot(x="species", y="petal_width", data=df, palette="Set3", ax=axes[1])
sns.boxplot(x="species", y="petal_length", data=df, palette="Set2", ax=axes[1])    
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("iris")
#两行一列共两个子图
fig,axes = plt.subplots(2,1)
#上子图垂直显示
sns.boxplot(x="species", y = "petal_width", data=df, orient="v", ax=axes[0])
#下子图水平显示
sns.boxplot(x="petal_length", y = "species", data=df, orient="h", ax=axes[1])
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#导入数据集
iris = pd.read_csv("iris.csv")
iris.columns=['sepal_length', 'speal_width', 'petal_length', 
             'petal_width', 'species']
#绘图
plt.figure(dpi=200)
sns.violinplot(x='species', y='sepal_length', data=iris, scale='width', inner='quartile')
#输出显示
plt.title("violin plot", fontsize=12)
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#导入数据集
iris = pd.read_csv("iris.csv")
iris.columns=['sepal_length', 'speal_width', 'petal_length', 
             'petal_width', 'species']
#绘图
plt.figure(dpi=200)
sns.violinplot(x='species', y='sepal_length', data=iris, split=True,scale='width', inner='box')
#输出显示
plt.title("violin plot", fontsize=12)
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

iris = pd.read_csv('iris.csv')
iris.columns=['sepal_length', 'sepal_width', 'petal_length', 
             'petal_width', 'species']
#绘图设置
fig,axes = plt.subplots(2, 2, figsize=(7,5), sharex=True)

sns.violinplot(x='species', y='sepal_length',
              data=iris, split=True, 
              scale='width', inner="box",
              ax=axes[0,0])
sns.violinplot(x='species', y='sepal_width',
              data=iris, split=True, 
              scale='width', inner="box",
              ax=axes[0,1])
sns.violinplot(x='species', y='petal_length',
              data=iris, split=True, 
              scale='width', inner="box",
              ax=axes[1,0])
sns.violinplot(x='species', y='petal_width',
              data=iris, split=True, 
              scale='width', inner="box",
              ax=axes[1,1])
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#用来正常显示中文标签
plt.rcParams['font.sans-serif']=['STHeiti']
#导入数据集
iris = pd.read_csv('iris.csv')
iris.columns=['sepal_length', 'sepal_width', 'petal_length', 
             'petal_width', 'species']
#绘图
sns.kdeplot(iris.loc[iris['species']== 'Iris-versicolor', 'sepal_length'], 
            shade=True, color='g', label="Iris-versicolor", alpha=.7)
sns.kdeplot(iris.loc[iris['species']== 'Iris-virginica', 'sepal_length'], 
            shade=True, color='deeppink', label="Iris-virginica", alpha=.7)
sns.kdeplot(iris.loc[iris['species']== 'Iris-setosa', 'sepal_length'], 
            shade=True, color='dodgerblue', label="Iris-setosa", alpha=.7)
plt.title('鸢尾花花瓣长度的密度图', fontsize=6)
plt.legend()
plt.show()
