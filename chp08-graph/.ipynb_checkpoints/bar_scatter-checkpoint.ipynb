# %%
import matplotlib.pyplot as plt
import numpy as np

#产生50对服从正太分布的样本点
npPointers = 50
x = np.random.standard_normal(npPointers)
y = np.random.standard_normal(npPointers)

#固定种子
np.random.seed(19680801)
colors = np.random.rand(npPointers)
area = (30 * np.random.rand(npPointers)) ** 2
plt.scatter(x, y, s = area, c = colors, alpha = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#读取文本数据
data = []
with open('iris.csv', 'r') as file:
    lines = file.readlines()
    for line in lines:
        temp = line.split(',')
        data.append(temp)

temp
#将列表转化为Numpy数组,方便后续处理
data_np = np.array(data)
data_np = np.array(data_np[:, :-1]).astype(float)
feature_name = ['speal length', 'sepal width', 'petal length', 'petal width']
fig,axes = plt.subplots(3,2, figsize = (20,10))
fig.suptitle('yidaihua', fontsize = 25)
#获取不同的特征组合,两两组合绘制散点图
i = 0 
for x in range(data_np.shape[1]):
    for y in range(x+1, data_np.shape[1]):
        
        X = data_np[:, x]
        Y = data_np[:, y]
        axes[i%3][i%2].scatter(X[:50], Y[:50], marker='x', c='b', label='setosa')
        axes[i%3][i%2].scatter(X[50:100], Y[50:100], marker='o', c='r', label='versicolor')
        axes[i%3][i%2].scatter(X[100:], Y[100:], marker='*', c='g', label='virginica')
        axes[i%3][i%2].set_xlabel(feature_name[x], fontsize=10)
        axes[i%3][i%2].set_ylabel(feature_name[y], fontsize=10)
        axes[i%3][i%2].legend(loc='best')
        i += 1   
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# 将全局的字体设置为黑体
plt.rcParams['font.family'] = 'SimHei'
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'List')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('用户量')
plt.title('数据分析程序语言使用分布情况')
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import numpy as np
import matplotlib.pyplot as plt
# 将全局的字体设置为黑体
plt.rcParams['font.family'] = 'SimHei'
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'List')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('用户量')
plt.title('数据分析程序语言使用分布情况')
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import numpy as np
import matplotlib.pyplot as plt
#用于绘制图形条的数据
n_group = 4 
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 200)
#创建图形
fig, ax = plt.subplots()
#定义条形图的横坐标上的分类位置
index = np.arange(n_group)

bar_width = 0.35
opacity = 0.8

#绘制第一个条形图
rects1 = plt.bar(index, #定义第一个条形图的X轴坐标信息
                 means_frank, #定义第一个条形图的Y轴坐标信息
                 bar_width, #定义图形的宽度
                 alpha = opacity, #定义图形的透明图
                 color='b', #定义图形颜色卫蓝色
                 label= 'zhangsan'
                )

#绘制第二个条形图
rects1 = plt.bar(index + bar_width, #定义第一个条形图的X轴坐标信息
                 means_guido, #定义第一个条形图的Y轴坐标信息
                 bar_width, #定义图形的宽度
                 alpha = opacity, #定义图形的透明图
                 color='g', #定义图形颜色卫蓝色
                 label= 'lisi'
                )

plt.xlabel('course')
plt.ylabel('score')
plt.title('score than')
plt.xticks(index+bar_width, ('A', 'B', 'C', 'D'))
plt.legend()
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import numpy as np
import matplotlib.pyplot as plt
#用于绘制图形条的数据
n_group = 4 
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 200)
#创建图形
fig, ax = plt.subplots()
#定义条形图的横坐标上的分类位置
index = np.arange(n_group)

bar_width = 0.35
opacity = 0.8

#绘制第一个条形图
rects1 = plt.bar(index, #定义第一个条形图的X轴坐标信息
                 means_frank, #定义第一个条形图的Y轴坐标信息
                 bar_width, #定义图形的宽度
                 alpha = opacity, #定义图形的透明图
                 color='w', edgecolor='k',
                 hatch='......',
                 label= 'zhangsan'
                )

#绘制第二个条形图
rects1 = plt.bar(index + bar_width, #定义第一个条形图的X轴坐标信息
                 means_guido, #定义第一个条形图的Y轴坐标信息
                 bar_width, #定义图形的宽度
                 alpha = opacity, #定义图形的透明图
                 color='w', edgecolor='k',
                 hatch='\\\\',
                 label= 'lisi'
                )

plt.xlabel('course')
plt.ylabel('score')
plt.title('score than')
plt.xticks(index+bar_width, ('A', 'B', 'C', 'D'))
plt.legend()
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import numpy as np
import matplotlib.pyplot as plt
#用于绘制图形条的数据
n_group = 4 
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 200)
#创建图形
fig, ax = plt.subplots()
#定义条形图的横坐标上的分类位置
index = np.arange(n_group)

bar_width = 0.35
opacity = 0.8

#绘制第一个条形图
rects1 = plt.bar(index, #定义第一个条形图的X轴坐标信息
                 means_frank, #定义第一个条形图的Y轴坐标信息
                 bar_width, #定义图形的宽度
                 alpha = opacity, #定义图形的透明图
                 color='w', edgecolor='k',
                 hatch='......',
                 label= 'zhangsan'
                )

#绘制第二个条形图
rects1 = plt.bar(index, #定义第一个条形图的X轴坐标信息
                 means_guido, #定义第一个条形图的Y轴坐标信息
                 bar_width, #定义图形的宽度
                 bottom = means_frank,
                 alpha = opacity, #定义图形的透明图
                 color='w', edgecolor='k',
                 hatch='\\\\',
                 label= 'lisi'
                )

plt.xlabel('course')
plt.ylabel('score')
plt.title('score than')
plt.xticks(index+bar_width, ('A', 'B', 'C', 'D'))
plt.legend()
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import numpy as np
import matplotlib.pyplot as plt

#平均数
mu = 100
#标准差
sigma = 15
#randn函数返回一个或一组样本，具有标准正态分布
x = mu + sigma * np.random.randn(200)
#划分的组数
num_bins = 25
#figsize:指定figure的宽和高，单位为英寸
#dpi参数指定绘图对象的分辨率，即每英寸多少个像素
plt.figure(figsize=(9,6), dpi=100)
n, bins, patches = plt.hist(x, 
                           num_bins, 
                           color='w', 
                           edgecolor='k',
                           hatch=r'ooo',
                           normed=True,
                           label='频率')

y = (( 1/(np.sqrt(2*np.pi) * sigma )) * np.exp(-0.5 * (1 / sigma * (bins-mu))**2))
plt.plot(bins, y , '--', label='概率密度函数')
plt.rcParams['font.sans-serif']=['SimHei']
plt.xlabel('聪明度')
plt.ylabel('概率密度')
plt.title("IQ直方图:$\mu=100$,$\sigma=15$")
plt.legend()
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/mathtext.py:866: MathTextWarning: Font 'default' does not have a glyph for '\u76f4' [U+76f4]
#   MathTextWarning)
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/mathtext.py:867: MathTextWarning: Substituting with a dummy symbol.
#   warn("Substituting with a dummy symbol.", MathTextWarning)
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/mathtext.py:866: MathTextWarning: Font 'default' does not have a glyph for '\u65b9' [U+65b9]
#   MathTextWarning)
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/mathtext.py:866: MathTextWarning: Font 'default' does not have a glyph for '\u56fe' [U+56fe]
#   MathTextWarning)

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/Users/magirui/.matplotlib/matplotlibrc'

# %%
import matplotlib.pyplot as plt
import numpy as np
#生成符合正太分布的5000个随机样本
x = np.random.normal(0,1,5000)
plt.figure(figsize=(14,7))
plt.style.use('seaborn-whitegrid') #设置绘图风格
n, bins, patches = plt.hist(x, bins=90, facecolor='#2ab0ff',
                           edgecolor='#169acf', linewidth=0.5)
n = n.astype('int')
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False #显示符号’-‘
#为每个条形设置颜色
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))

#对某个特定条形做特别说明
patches[49].set_fc('red')
patches[49].set_alpha(1)
#添加注释
plt.annotate('这是一个重要条形', xy=(0.6,155), xytext=(1.5,130),
            fontsize=15, arrowprops={'width':0.4, 'color':'#333333'})
plt.title('正太分布', fontsize=12)
plt.xlabel('不同的间隔(bins)', fontsize = 10)
plt.ylabel('频度大小', fontsize=10)
plt.show()
# Out:
# /Users/magirui/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import matplotlib    
print(matplotlib.matplotlib_fname())
# Out:
# /Users/magirui/.matplotlib/matplotlibrc

# %%
import matplotlib as mpl
fm = mpl.font_manager
fm.get_cachedir()
# Out:
# '/Users/magirui/.matplotlib'
